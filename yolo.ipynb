# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())
print(torch.cuda.device(0))
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# 0
# <torch.cuda.device object at 0x000001B8E55F01D0>
# NVIDIA GeForce RTX 3060 Ti

# %%
from ultralytics import YOLO #i boni 17 21
#model = YOLO('yolov8n.pt')   # choose a pretrained model
model = YOLO(r'C:\Users\Cesare\Desktop\chitarra\runs\detect\train22\weights\last.pt')   # choose a pretrained model
model.train(data='data.yaml', epochs=200, imgsz=1080, batch=16, verbose=False, plots=False, resume=True, cfg='hyp.yaml')
# Out:
# New https://pypi.org/project/ultralytics/8.3.192 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191  Python-3.11.9 torch-2.8.0+cu129 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8191MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=hyp.yaml, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.2, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=200, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1080, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=C:\Users\Cesare\Desktop\chitarra\runs\detect\train22\weights\last.pt, momentum=0.937, mosaic=0.2, multi_scale=False, name=train22, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=False, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=C:\Users\Cesare\Desktop\chitarra\runs\detect\train22\weights\last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\detect\train22, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=2.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    757357  ultralytics.nn.modules.head.Detect           [31, [64, 128, 256]]
# Model summary: 129 layers, 3,016,893 parameters, 3,016,877 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# WARNING imgsz=[1080] must be multiple of max stride 32, updating to [1088]
# train: Fast image access  (ping: 0.30.1 ms, read: 92.720.7 MB/s, size: 50.9 KB)
# train: Scanning C:\Users\Cesare\Desktop\chitarra\dataset\labels\train.cache... 2000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2000/2000 1990652.1it/s 0.0s
# val: Fast image access  (ping: 0.20.0 ms, read: 53.525.3 MB/s, size: 23.1 KB)
# val: Scanning C:\Users\Cesare\Desktop\chitarra\dataset\labels\val.cache... 200 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 200062.2it/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000286, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Resuming training C:\Users\Cesare\Desktop\chitarra\runs\detect\train22\weights\last.pt from epoch 46 to 200 total epochs
# Image sizes 1088 train, 1088 val
# Using 8 dataloader workers
# Logging results to runs\detect\train22
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/200        12G     0.8429      0.926     0.7783       1209       1088: 100% ━━━━━━━━━━━━ 125/125 0.47it/s 4:25.5sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.9it/s 1.4s0.3s
#                    all        200       2810      0.986      0.991      0.995      0.906
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/200      14.7G     0.8343     0.9096     0.7766       1391       1088: 100% ━━━━━━━━━━━━ 125/125 0.38it/s 5:312.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 5.1it/s 1.4s0.3s
#                    all        200       2810      0.991      0.991      0.994       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/200      16.4G     0.8493     0.9232     0.7768       1232       1088: 100% ━━━━━━━━━━━━ 125/125 0.70it/s 2:573.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.2s0.3s0s
#                    all        200       2810      0.992      0.989      0.995      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/200        13G     0.8239     0.8964      0.778        745       1088: 100% ━━━━━━━━━━━━ 125/125 0.53it/s 3:56.7sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 5.2it/s 1.3s0.2s
#                    all        200       2810      0.992      0.989      0.995      0.905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/200      14.7G     0.8264     0.8897     0.7779        938       1088: 100% ━━━━━━━━━━━━ 125/125 0.50it/s 4:082.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.8it/s 1.4s0.3s
#                    all        200       2810      0.989      0.989      0.994      0.905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/200      11.8G      0.826     0.8972     0.7763        778       1088: 100% ━━━━━━━━━━━━ 125/125 0.48it/s 4:21.9sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 5.5it/s 1.3s0.2s
#                    all        200       2810      0.993      0.989      0.995      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/200      14.4G     0.8131     0.8813     0.7762       1048       1088: 100% ━━━━━━━━━━━━ 125/125 0.58it/s 3:34.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 5.5it/s 1.3s0.2s
#                    all        200       2810      0.993      0.991      0.994      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/200      11.8G     0.8113     0.8706     0.7763        738       1088: 100% ━━━━━━━━━━━━ 125/125 0.51it/s 4:07.6sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 5
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\ultralytics\engine\model.py:801, in Model.train(self, trainer, **kwargs)
#     798     self.model = self.trainer.model
#     800 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 801 self.trainer.train()
#     802 # Update model and cfg after training
#     803 if RANK in {-1, 0}:
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\ultralytics\engine\trainer.py:230, in BaseTrainer.train(self)
#     227         ddp_cleanup(self, str(file))
#     229 else:
# --> 230     self._do_train(world_size)
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\ultralytics\engine\trainer.py:407, in BaseTrainer._do_train(self, world_size)
#     405 with autocast(self.amp):
#     406     batch = self.preprocess_batch(batch)
# --> 407     loss, self.loss_items = self.model(batch)
#     408     self.loss = loss.sum()
#     409     if RANK != -1:
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\ultralytics\nn\tasks.py:138, in BaseModel.forward(self, x, *args, **kwargs)
#     124 """
#     125 Perform forward pass of the model for either training or inference.
#     126
#    (...)    135     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     136 """
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 138     return self.loss(x, *args, **kwargs)
#     139 return self.predict(x, *args, **kwargs)
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\ultralytics\nn\tasks.py:338, in BaseModel.loss(self, batch, preds)
#     335     self.criterion = self.init_criterion()
#     337 preds = self.forward(batch["img"]) if preds is None else preds
# --> 338 return self.criterion(preds, batch)
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\ultralytics\utils\loss.py:272, in v8DetectionLoss.__call__(self, preds, batch)
#     268 pred_bboxes = self.bbox_decode(anchor_points, pred_distri)  # xyxy, (b, h*w, 4)
#     269 # dfl_conf = pred_distri.view(batch_size, -1, 4, self.reg_max).detach().softmax(-1)
#     270 # dfl_conf = (dfl_conf.amax(-1).mean(-1) + dfl_conf.amax(-1).amin(-1)) / 2
# --> 272 _, target_bboxes, target_scores, fg_mask, _ = self.assigner(
#     273     # pred_scores.detach().sigmoid() * 0.8 + dfl_conf.unsqueeze(-1) * 0.2,
#     274     pred_scores.detach().sigmoid(),
#     275     (pred_bboxes.detach() * stride_tensor).type(gt_bboxes.dtype),
#     276     anchor_points * stride_tensor,
#     277     gt_labels,
#     278     gt_bboxes,
#     279     mask_gt,
#     280 )
#     282 target_scores_sum = max(target_scores.sum(), 1)
#     284 # Cls loss
#     285 # loss[1] = self.varifocal_loss(pred_scores, target_scores, target_labels) / target_scores_sum  # VFL way
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\ultralytics\utils\tal.py:84, in TaskAlignedAssigner.forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      75     return (
#      76         torch.full_like(pd_scores[..., 0], self.num_classes),
#      77         torch.zeros_like(pd_bboxes),
#    (...)     80         torch.zeros_like(pd_scores[..., 0]),
#      81     )
#      83 try:
# ---> 84     return self._forward(pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      85 except torch.cuda.OutOfMemoryError:
#      86     # Move tensors to CPU, compute, then move back to original device
#      87     LOGGER.warning("CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU")
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\ultralytics\utils\tal.py:111, in TaskAlignedAssigner._forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      92 def _forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt):
#      93     """
#      94     Compute the task-aligned assignment.
#      95
#    (...)    109         target_gt_idx (torch.Tensor): Target ground truth indices with shape (bs, num_total_anchors).
#     110     """
# --> 111     mask_pos, align_metric, overlaps = self.get_pos_mask(
#     112         pd_scores, pd_bboxes, gt_labels, gt_bboxes, anc_points, mask_gt
#     113     )
#     115     target_gt_idx, fg_mask, mask_pos = self.select_highest_overlaps(mask_pos, overlaps, self.n_max_boxes)
#     117     # Assigned target
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\ultralytics\utils\tal.py:148, in TaskAlignedAssigner.get_pos_mask(self, pd_scores, pd_bboxes, gt_labels, gt_bboxes, anc_points, mask_gt)
#     146 mask_in_gts = self.select_candidates_in_gts(anc_points, gt_bboxes)
#     147 # Get anchor_align metric, (b, max_num_obj, h*w)
# --> 148 align_metric, overlaps = self.get_box_metrics(pd_scores, pd_bboxes, gt_labels, gt_bboxes, mask_in_gts * mask_gt)
#     149 # Get topk_metric mask, (b, max_num_obj, h*w)
#     150 mask_topk = self.select_topk_candidates(align_metric, topk_mask=mask_gt.expand(-1, -1, self.topk).bool())
#
# File c:\Users\Cesare\Desktop\chitarra\.venv\Lib\site-packages\ultralytics\utils\tal.py:183, in TaskAlignedAssigner.get_box_metrics(self, pd_scores, pd_bboxes, gt_labels, gt_bboxes, mask_gt)
#     180 bbox_scores[mask_gt] = pd_scores[ind[0], :, ind[1]][mask_gt]  # b, max_num_obj, h*w
#     182 # (b, max_num_obj, 1, 4), (b, 1, h*w, 4)
# --> 183 pd_boxes = pd_bboxes.unsqueeze(1).expand(-1, self.n_max_boxes, -1, -1)[mask_gt]
#     184 gt_boxes = gt_bboxes.unsqueeze(2).expand(-1, -1, na, -1)[mask_gt]
#     185 overlaps[mask_gt] = self.iou_calculation(gt_boxes, pd_boxes)
#
# KeyboardInterrupt:

# %%
model = YOLO("runs/detect/train15/weights/best.pt")
metrics = model.val(data="data.yaml")
print(metrics)

# %%
import cv2
import os

model = YOLO("runs/detect/train22/weights/best.pt")

input_folder = "prove_songsterr"
output_folder = "prove_songsterr_inverted"
os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
        img_path = os.path.join(input_folder, filename)
        img = cv2.imread(img_path)
        if img is not None:
            inverted_img = cv2.bitwise_not(img)
            cv2.imwrite(os.path.join(output_folder, filename), inverted_img)

# Run prediction on a folder of test images
results = model.predict(source="prove_songsterr_inverted", conf=0.25, imgsz=2000)

for r in results:
    r.show()
# Out:
# WARNING imgsz=[2000] must be multiple of max stride 32, updating to [2016]
# image 1/6 c:\Users\Cesare\Desktop\chitarra\prove_songsterr_inverted\0_sl.jpg: 192x2016 3 0s, 1 1, 1 2, 2 3s, 2 4s, 2 5s, 3 6s, 1 7, 3 8s, 2 9s, 2 10s, 1 11, 3 12s, 2 13s, 1 14, 3 15s, 4 16s, 3 17s, 2 18s, 1 20, 1 23, 1 24, 5 25s, 2 26s, 4 27s, 1 28, 2 29s, 3 30s, 68.8ms
# image 2/6 c:\Users\Cesare\Desktop\chitarra\prove_songsterr_inverted\a.png: 320x2016 1 2, 1 4, 8 5s, 1 6, 3 7s, 2 8s, 1 21, 92.4ms
# image 3/6 c:\Users\Cesare\Desktop\chitarra\prove_songsterr_inverted\b.png: 192x2016 1 7, 12 12s, 11 14s, 4 15s, 1 16, 2 30s, 41.5ms
# image 4/6 c:\Users\Cesare\Desktop\chitarra\prove_songsterr_inverted\c.png: 480x2016 5 12s, 2 14s, 4 15s, 1 16, 1 17, 288.5ms
# image 5/6 c:\Users\Cesare\Desktop\chitarra\prove_songsterr_inverted\d.png: 384x2016 4 12s, 5 14s, 264.8ms
# image 6/6 c:\Users\Cesare\Desktop\chitarra\prove_songsterr_inverted\e.png: 960x2016 1 5, 2 7s, 1 9, 1 19, 207.6ms
# Speed: 4.5ms preprocess, 160.6ms inference, 2.0ms postprocess per image at shape (1, 3, 960, 2016)
